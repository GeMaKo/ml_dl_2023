# %% [markdown]
# Based on a talk by Dr. Adrin Jalali https://github.com/adrinjalali/talks/tree/master/2018/CNNs-long

# %% [markdown]
# # Neural Networks, Tensorflow, Deep Learning

# %% [markdown]
# #### Requirements:
#
#  - python3
#  - ipython
#  - notebook (jupyter)
#  - matplotlib
#  - numpy, pandas
#  - keras
#  - tensorflow

# %% [markdown]
# ## Neural Networks

# %% [markdown]
# ### A single neuron
#
# ![spiking neural network](http://lis2.epfl.ch/CompletedResearchProjects/EvolutionOfAdaptiveSpikingCircuits/images/neuron.jpg)

# %% [markdown]
# ### Spiking Neural Networks
#
# ![spiking system](http://lis2.epfl.ch/CompletedResearchProjects/EvolutionOfAdaptiveSpikingCircuits/images/spiking.jpg)

# %% [markdown]
# ### Artificial Neuron (Perceptron - 1957)
# [Source](http://natureofcode.com/book/chapter-10-neural-networks/)
#
# ![](http://natureofcode.com/book/imgs/chapter10/ch10_05.png)
#
# $$output = f(x \times w_x + y \times w_y)$$
# $$f(x) = sign(x)$$
#
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Signum_function.svg/200px-Signum_function.svg.png)

# %% [markdown]
# ### Classification
#
# ![](http://natureofcode.com/book/imgs/chapter10/ch10_04.png)

# %% [markdown]
# #### Add bias
# ![](http://natureofcode.com/book/imgs/chapter10/ch10_06.png)
#
# $$output = f(x \times w_x + y \times w_y + bias \times w_{bias})$$
# $$f(x) = sign(x)$$

# %% [markdown]
# #### Feed the data
# ![](http://natureofcode.com/book/imgs/chapter10/ch10_07.png)

# %% [markdown]
# ### Excercise: derive the weight update formula.

# %% [markdown]
# $$output = sign(x \times w_x + y \times w_y + b \times w_b)$$

# %% [markdown]
# $$error = desired - output$$

# %% [markdown]
# $$w_{new} = w + \Delta w$$

# %% [markdown]
# $$\Delta w = error \times input$$

# %% [markdown]
# $$\Delta w =  error \times input \times \text{learning rate}$$

# %% [markdown]
# ## Classification
#
# ### Logical OR
#
# #### Initialize variables

# %%
import numpy as np
import math

sign = lambda x: math.copysign(1, x)

def f(X, W):
    return sign(sum([x * w for x, w in zip(X, W)]))

data = np.array([[0, 0, 1],
                 [1, 0, 1],
                 [0, 1, 1],
                 [1, 1, 1]])
output = np.array([-1, 1, 1, 1])

W = np.random.normal(0, size=3)

# %% [markdown]
# #### Error

# %%
for i in range(len(data)):
    print('desired: %2d, expected: %2d, error: %2d' % 
          (f(data[i], W), 
           output[i],
           output[i] - f(data[i], W)))
# Out:
# desired: -1, expected: -1, error:  0
# desired:  1, expected:  1, error:  0
# desired: -1, expected:  1, error:  2
# desired: -1, expected:  1, error:  2

# %%
def total_error(X, W, y):
    return sum([abs(y[i] - f(X[i,], W)) for i in range(len(X))])

# %% [markdown]
# #### Update Weights

# %%
def new_w(X, W, y, learning_rate):
    output = f(X, W)
    error = y - output
    delta_w = np.array([error * x * learning_rate for x in X])
    return W + delta_w

# %% [markdown]
# #### Train

# %%
learning_rate = 0.5
print('starting error: %2g' % total_error(data, W, output))

for epoch in range(100):
    for i in range(len(data)):
        W = new_w(data[i,:], W, output[i], learning_rate)
        
    print('error: %2g, W: %s' % (total_error(data, W, output), str(W)))
    if total_error(data, W, output) == 0:
        break
# Out:
# starting error:  4
# error:  2, W: [0.33557582 0.72169877 0.07400646]
# error:  2, W: [1.33557582 0.72169877 0.07400646]
# error:  2, W: [1.33557582 1.72169877 0.07400646]
# error:  0, W: [ 1.33557582  1.72169877 -0.92599354]

# %% [markdown]
# ### Logical AND
#
# #### Initialize variables

# %%
data = np.array([[0, 0, 1],
                 [1, 0, 1],
                 [0, 1, 1],
                 [1, 1, 1]])
output = np.array([-1, -1, -1, 1])

W = np.random.normal(0, size=3)

# %% [markdown]
# #### Train

# %%
learning_rate = 0.5
print('starting error: %2g' % total_error(data, W, output))

for epoch in range(100):
    for i in range(len(data)):
        W = new_w(data[i,:], W, output[i], learning_rate)
        
    print('error: %2g, W: %s' % (total_error(data, W, output), str(W)))
    if total_error(data, W, output) == 0:
        break
# Out:
# starting error:  6
# error:  6, W: [-0.12756509  0.94978059  0.53770613]
# error:  4, W: [ 0.87243491  0.94978059 -0.46229387]
# error:  4, W: [ 0.87243491  1.94978059 -0.46229387]
# error:  2, W: [ 0.87243491  1.94978059 -1.46229387]
# error:  4, W: [ 1.87243491  1.94978059 -1.46229387]
# error:  0, W: [ 0.87243491  1.94978059 -2.46229387]

# %% [markdown]
# ### Demo
# http://natureofcode.com/book/chapter-10-neural-networks/
#
# https://bit.ly/1QwqTmA

# %% [markdown]
# ### Logical XOR
#
# #### Initialize variables

# %%
data = np.array([[0, 0, 1],
                 [1, 0, 1],
                 [0, 1, 1],
                 [1, 1, 1]])
output = np.array([-1, 1, 1, -1])

W = np.random.normal(0, size=3)

# %% [markdown]
# #### Train

# %%
learning_rate = 0.1
print('starting error: %2g' % total_error(data, W, output))

for epoch in range(100):
    for i in range(len(data)):
        W = new_w(data[i,:], W, output[i], learning_rate)
        
    print('error: %2g, W: %s' % (total_error(data, W, output), str(W)))
    if total_error(data, W, output) == 0:
        break
# Out:
# starting error:  4
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]

# %% [markdown]
# #### Train (observe more closely)

# %%
learning_rate = 0.1
print('starting error: %2g' % total_error(data, W, output))

for epoch in range(100):
    for i in range(len(data)):
        W = new_w(data[i,:], W, output[i], learning_rate)
        
        print('error: %2g, W: %s' % (total_error(data, W, output), str(W)))
    if total_error(data, W, output) == 0:
        break
# Out:
# starting error:  4
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]
# error:  6, W: [-0.35259378 -0.47298198  0.18096587]
# error:  4, W: [-0.15259378 -0.47298198  0.38096587]
# error:  4, W: [-0.15259378 -0.27298198  0.58096587]
# error:  4, W: [-0.35259378 -0.47298198  0.38096587]

# %% [markdown]
# ### Linear Separability
#
# ![](http://natureofcode.com/book/imgs/chapter10/ch10_12.png)
# ![](http://natureofcode.com/book/imgs/chapter10/ch10_13.png)

# %% [markdown]
# #### Multilayer perceptron
# ![](http://natureofcode.com/book/imgs/chapter10/ch10_14.png)

# %% [markdown]
# ## Regression

# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

x = np.random.randint(100, size=30)
y = 10 * x - 40 + np.random.normal(size=30) * 40

x = x.reshape(-1, 1)
data = np.hstack((x, np.ones_like(x)))

plt.scatter(x, y)

# %%
def f(X, W):
    return sum([x * w for x, w in zip(X, W)])

def new_w(X, W, y, learning_rate):
    output = f(X, W)
    error = y - output
    delta_w = np.array([error * x * learning_rate for x in X])
    return W + delta_w

def total_error(X, W, y):
    return sum([abs(y[i] - f(X[i,], W)) for i in range(len(X))])

# %%
learning_rate = 0.00001
W = np.random.normal(size=2)

for epoch in range(20000):
    if epoch % 2000 == 0:
        print('error: %2g, W: %s' % (total_error(data, W, y), str(W)))
        
    for i in range(len(data)):
        W = new_w(data[i,], W, y[i], learning_rate)
# Out:
# error: 17954.5, W: [-2.2934314   2.12326954]
# error: 1018.1, W: [ 9.47605474 -1.42954132]
# error: 1009.45, W: [ 9.52879993 -4.7807015 ]
# error: 1004.61, W: [ 9.57608397 -7.78488876]
# error: 1001.35, W: [  9.61847232 -10.47802803]
# error: 998.428, W: [  9.65647185 -12.89232465]
# error: 995.81, W: [  9.69053698 -15.05664947]
# error: 993.463, W: [  9.72107507 -16.99688411]
# error: 991.849, W: [  9.74845131 -18.73623044]
# error: 992.198, W: [  9.77299305 -20.29548808]

# %%
from IPython.display import clear_output
import time

def plot(data, y, W):
    plt.scatter(data[:,0], y)
    plt.plot([0, 100], [f([0, 1], W), f([100, 1], W)])
    plt.title('error: %2g, W: %s' % (total_error(data, W, y), str(W)))
    plt.show()
    
learning_rate = 0.00001
W = np.random.normal(size=2)

for epoch in range(10):
    clear_output()
    plot(data, y, W)
    time.sleep(1)
        
    for i in range(len(data)):
        W = new_w(data[i,], W, y[i], learning_rate)

# %% [markdown]
# #### Dynamic Learning Rate

# %%
learning_rate = 0.0001
W = np.random.normal(size=2)

for epoch in range(20000):
    if epoch % 2000 == 0:
        print('error: %2g, W: %s, lr: %4g' % (total_error(data, W, y), str(W), learning_rate))
        learning_rate = learning_rate * 0.9
        
    for i in range(len(data)):
        W = new_w(data[i,], W, y[i], learning_rate)
        
    if total_error(data, W, y) == 0:
        break
# Out:
# error: 14130, W: [ 0.23995477 -1.03353337], lr: 0.0001
# error: 1061.4, W: [  9.70526436 -27.51902571], lr: 9e-05
# error: 1055.6, W: [  9.86787685 -36.02993464], lr: 8.1e-05
# error: 1049.92, W: [  9.93829393 -38.72615537], lr: 7.29e-05
# error: 1042.23, W: [  9.97206687 -39.39924623], lr: 6.561e-05
# error: 1035.12, W: [  9.9890672  -39.33270017], lr: 5.9049e-05
# error: 1029.17, W: [  9.99748939 -38.9959479 ], lr: 5.31441e-05
# error: 1024.32, W: [ 10.00124614 -38.5714701 ], lr: 4.78297e-05
# error: 1020.34, W: [ 10.00245045 -38.13317989], lr: 4.30467e-05
# error: 1017.01, W: [ 10.00233254 -37.71142417], lr: 3.8742e-05

# %% [markdown]
# ## Iterative Approach
# ![](./figs/iterative.png)

# %% [markdown]
# ![](figs/loss1.png)

# %% [markdown]
# ![](figs/loss2.png)

# %% [markdown]
# ![](figs/loss3.png)

# %% [markdown]
# ![](figs/loss4.png)

# %% [markdown]
# ![](figs/lr1.png)

# %% [markdown]
# ![](figs/lr2.png)

# %% [markdown]
# ![](figs/lr3.png)

# %% [markdown]
# ### Activation Functions: [wiki](https://en.wikipedia.org/wiki/Activation_function)
# https://en.wikipedia.org/wiki/Activation_function
#
# ![](./figs/activation-funcs.png)

# %% [markdown]
# ## Convolutional Neural Networks (CNN)
#
# ![](https://upload.wikimedia.org/wikipedia/commons/6/63/Typical_cnn.png)
#
# ### Weight Sharing, Convolution

# %% [markdown]
# ### Max Pooling
# ![](https://upload.wikimedia.org/wikipedia/commons/e/e9/Max_pooling.png)
#
# ### Dropout, {L1, L2} regularization, artificial data, etc.

# %% [markdown]
# ### Keras
# #### keras.io
#
# ![](figs/keras.png)

# %% [markdown]
# # MNIST
#
# ![](http://andrea.burattin.net/public-files/stuff/handwritten-digit-recognition/example_mnist.gif)

# %% [markdown]
# # MNIST
#
# ![](figs/mnist-perfs.png)
#
# ### Based on keras examples, specifically [this one](https://github.com/fchollet/keras/blob/master/examples/mnist_cnn.py)

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
# Out:
# 2023-09-13 07:32:50.778158: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
batch_size = 128
num_classes = 10
epochs = 12

# input image dimensions
img_rows, img_cols = 28, 28

# the data, shuffled and split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/12
# 469/469 [==============================] - 43s 91ms/step - loss: 2.2812 - accuracy: 0.1543 - val_loss: 2.2393 - val_accuracy: 0.3435
# Epoch 2/12
# 469/469 [==============================] - 47s 100ms/step - loss: 2.2154 - accuracy: 0.2695 - val_loss: 2.1592 - val_accuracy: 0.4617
# Epoch 3/12
# 469/469 [==============================] - 50s 107ms/step - loss: 2.1324 - accuracy: 0.3568 - val_loss: 2.0549 - val_accuracy: 0.5714
# Epoch 4/12
# 469/469 [==============================] - 51s 108ms/step - loss: 2.0250 - accuracy: 0.4299 - val_loss: 1.9171 - val_accuracy: 0.6617
# Epoch 5/12
# 469/469 [==============================] - 52s 111ms/step - loss: 1.8872 - accuracy: 0.4957 - val_loss: 1.7462 - val_accuracy: 0.7215
# Epoch 6/12
# 469/469 [==============================] - 53s 112ms/step - loss: 1.7282 - accuracy: 0.5481 - val_loss: 1.5526 - val_accuracy: 0.7472
# Epoch 7/12
# 469/469 [==============================] - 51s 109ms/step - loss: 1.5590 - accuracy: 0.5901 - val_loss: 1.3549 - val_accuracy: 0.7705
# Epoch 8/12
# 469/469 [==============================] - 53s 112ms/step - loss: 1.4008 - accuracy: 0.6218 - val_loss: 1.1741 - val_accuracy: 0.7906
# Epoch 9/12
# 469/469 [==============================] - 53s 113ms/step - loss: 1.2644 - accuracy: 0.6453 - val_loss: 1.0241 - val_accuracy: 0.8064
# Epoch 10/12
# 469/469 [==============================] - 53s 112ms/step - loss: 1.1509 - accuracy: 0.6707 - val_loss: 0.9051 - val_accuracy: 0.8198
# Epoch 11/12
# 469/469 [==============================] - 51s 109ms/step - loss: 1.0621 - accuracy: 0.6912 - val_loss: 0.8125 - val_accuracy: 0.8313
# Epoch 12/12
# 469/469 [==============================] - 53s 114ms/step - loss: 0.9890 - accuracy: 0.7071 - val_loss: 0.7394 - val_accuracy: 0.8405
# Test loss: 0.7393900752067566
# Test accuracy: 0.840499997138977

# %% [markdown]
# #### Keras
# https://github.com/fchollet/keras/blob/master/examples/mnist_cnn.py
#
# https://bit.ly/2HzzSKp

# %% [markdown]
# ### Good old scikit-learn & linear regression

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import VarianceThreshold
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler

pipeline = Pipeline([
    ('variance filter', VarianceThreshold(threshold=0.01)),
    ('standard_scale', StandardScaler()),
    ('estimator', Lasso(alpha=0.1, max_iter=2000)),
])

pipeline.fit(x_train.reshape(60000, -1), y_train)
# Out:
# Pipeline(steps=[('variance filter', VarianceThreshold(threshold=0.01)),
#                 ('standard_scale', StandardScaler()),
#                 ('estimator', Lasso(alpha=0.1, max_iter=2000))])

# %%
from sklearn.metrics import label_ranking_average_precision_score
label_ranking_average_precision_score(y_test, pipeline.predict(x_test.reshape(len(x_test), -1)))
# Out:
# 0.47801019841269715

# %%
label_ranking_average_precision_score(y_test, model.predict(x_test))
# Out:
# 313/313 [==============================] - 4s 12ms/step
# 0.903410277777777

# %% [markdown]
# ### Convolution Kernels
# ![](figs/convolution-kernels.png)
# [Source](https://www.jebruner.com/2017/07/interpreting-and-fooling-convolutional-neural-networks-part-1/)
